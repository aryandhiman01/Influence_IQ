# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sqlalchemy import create_engine

from dotenv import load_dotenv

import os

# %%
load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")

engine = create_engine(DATABASE_URL)

# %%
channels_df = pd.read_sql(
    "SELECT * FROM channels",
    engine
)

videos_df = pd.read_sql(
    "SELECT * FROM videos",
    engine
)

comments_df = pd.read_sql(
    "SELECT * FROM comments",
    engine
)

# %%
print("Channels :", channels_df.shape)

print("Videos :", videos_df.shape)

print("Comments :", comments_df.shape)
# Out:
# Channels : (1, 8)
# Videos : (50, 13)
# Comments : (4200, 21)

# %%
channels_df.head()
# Out:
#                  channel_id  channel_name  \
# 0  UCBwmMxybNva6P_5VmxjzwqA  Apna College
#
#                                          description country  \
# 0  Started with a vision to provide learning that...    None
#
#                   published_at  subscriber_count  total_views  video_count
# 0  2020-08-05T16:09:28.304314Z           7700000   1284141607         1028

# %%
comments_df.head()
# Out:
#                    comment_id     video_id              author  \
# 0  Ugws4i6EzTKpFxqnwqx4AaABAg  w9319SXPOmg    @MalaKumari-4436
# 1  Ugwtpj36gDxyrVsoh_t4AaABAg  oGdt3tzo074    @RajeevMishra498
# 2  UgwvhcaqBZYWrCRlgRB4AaABAg  Tc_MJZ8XYYc  @parthvibhagat8272
# 3  Ugww-l1mXA_nwkbUkb14AaABAg  sMUWg_OlbbY      @himeshkar-g2f
# 4  Ugww_5huF7wSfdKgrwx4AaABAg  Ebe9NFgQnnU        @Sonali33669
#
#                                              comment  likes  \
# 0  Didi ye bataeye ki mujhe English me koe bhi su...      0
# 1              Pls make an video on software Testing      0
# 2  Hi ma'am, are you providing Data science roles...      0
# 3  6:02 i am also helping and is a part of making...      0
# 4  Can we start DSA with python  instead of C++/j...      0
#
#            published_at  is_cleaned sentiment  is_spam  \
# 0  2026-02-21T06:50:29Z        True   Neutral    False
# 1  2026-06-10T07:11:53Z        True  Positive    False
# ...

# %%
channels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        1 non-null      object
#  1   channel_name      1 non-null      object
#  2   description       1 non-null      object
#  3   country           0 non-null      object
#  4   published_at      1 non-null      object
#  5   subscriber_count  1 non-null      int64
#  6   total_views       1 non-null      int64
#  7   video_count       1 non-null      int64
# dtypes: int64(3), object(5)
# memory usage: 196.0+ bytes

# %%
channels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        1 non-null      object
#  1   channel_name      1 non-null      object
#  2   description       1 non-null      object
#  3   country           0 non-null      object
#  4   published_at      1 non-null      object
#  5   subscriber_count  1 non-null      int64
#  6   total_views       1 non-null      int64
#  7   video_count       1 non-null      int64
# dtypes: int64(3), object(5)
# memory usage: 196.0+ bytes

# %%
comments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   comment_id                 4200 non-null   object
#  1   video_id                   4200 non-null   object
#  2   author                     4200 non-null   object
#  3   comment                    4200 non-null   object
#  4   likes                      4200 non-null   int64
#  5   published_at               4200 non-null   object
#  6   is_cleaned                 4200 non-null   bool
#  7   sentiment                  4200 non-null   object
#  8   is_spam                    4200 non-null   bool
#  9   contains_abusive_language  4200 non-null   bool
#  10  clean_comment              4200 non-null   object
#  11  is_spam_checked            4200 non-null   bool
#  12  is_sentiment_checked       4200 non-null   bool
# ...

# %%
channels_df.describe(include="all")
# Out:
#                       channel_id  channel_name  \
# count                          1             1
# unique                         1             1
# top     UCBwmMxybNva6P_5VmxjzwqA  Apna College
# freq                           1             1
# mean                         NaN           NaN
# std                          NaN           NaN
# min                          NaN           NaN
# 25%                          NaN           NaN
# 50%                          NaN           NaN
# 75%                          NaN           NaN
# max                          NaN           NaN
#
#                                               description country  \
# count                                                   1       0
# unique                                                  1       0
# top     Started with a vision to provide learning that...     NaN
# freq                                                    1     NaN
# ...

# %%
videos_df.describe(include="all")
# Out:
#            video_id                channel_id  \
# count            50                        50
# unique           50                         1
# top     c-HkAo8Bho4  UCBwmMxybNva6P_5VmxjzwqA
# freq              1                        50
# mean            NaN                       NaN
# std             NaN                       NaN
# min             NaN                       NaN
# 25%             NaN                       NaN
# 50%             NaN                       NaN
# 75%             NaN                       NaN
# max             NaN                       NaN
#
#                                                     title description  \
# count                                                  50          50
# unique                                                 50          28
# top     When is the Best Time to start Coding for Plac...
# freq                                                    1          14
# ...

# %%
comments_df.describe(include="all")
# Out:
#                         comment_id     video_id            author comment  \
# count                         4200         4200              4200    4200
# unique                        4200           50              3598    3840
# top     Ugws4i6EzTKpFxqnwqx4AaABAg  w9319SXPOmg  @ravangaming6008      ❤️
# freq                             1          100                25      46
# mean                           NaN          NaN               NaN     NaN
# std                            NaN          NaN               NaN     NaN
# min                            NaN          NaN               NaN     NaN
# 25%                            NaN          NaN               NaN     NaN
# 50%                            NaN          NaN               NaN     NaN
# 75%                            NaN          NaN               NaN     NaN
# max                            NaN          NaN               NaN     NaN
#
#               likes          published_at is_cleaned sentiment is_spam  \
# ...

# %%
channels_df.isnull().sum()
# Out:
# channel_id          0
# channel_name        0
# description         0
# country             1
# published_at        0
# subscriber_count    0
# total_views         0
# video_count         0
# dtype: int64

# %%
videos_df.isnull().sum()
# Out:
# video_id             0
# channel_id           0
# title                0
# description          0
# published_at         0
# thumbnail            0
# view_count           0
# like_count           0
# comment_count        0
# duration             0
# category_id          0
# default_language     0
# tags                16
# dtype: int64

# %%
comments_df.isnull().sum()
# Out:
# comment_id                   0
# video_id                     0
# author                       0
# comment                      0
# likes                        0
# published_at                 0
# is_cleaned                   0
# sentiment                    0
# is_spam                      0
# contains_abusive_language    0
# clean_comment                0
# is_spam_checked              0
# is_sentiment_checked         0
# is_abusive_checked           0
# word_count                   0
# character_count              0
# comment_length               0
# contains_link                0
# contains_question            0
# contains_exclamation         0
# is_feature_engineered        0
# dtype: int64

# %%
print("Channels :", channels_df.duplicated().sum())

print("Videos :", videos_df.duplicated().sum())

print("Comments :", comments_df.duplicated().sum())
# Out:
# Channels : 0
# Videos : 0
# Comments : 0

# %%
channels_df[
    [
        "subscriber_count",
        "total_views",
        "video_count"
    ]
]
# Out:
#    subscriber_count  total_views  video_count
# 0           7700000   1284141607         1028

# %%
plt.figure(figsize=(8,5))

plt.bar(

    channels_df["channel_name"],

    channels_df["subscriber_count"]

)

plt.title("Subscriber Count")

plt.ylabel("Subscribers")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(

    channels_df["channel_name"],

    channels_df["total_views"]

)

plt.title("Total Views")

plt.ylabel("Views")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(

    channels_df["channel_name"],

    channels_df["video_count"]

)

plt.title("Video Count")

plt.ylabel("Videos")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(

    videos_df["view_count"],

    bins=20

)

plt.title("Video View Distribution")

plt.xlabel("Views")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(

    videos_df["like_count"],

    bins=20

)

plt.title("Like Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(

    videos_df["comment_count"],

    bins=20

)

plt.title("Comment Distribution")

plt.show()

# %%
top_views = videos_df.nlargest(
    10,
    "view_count"
)

top_views[
    [
        "title",
        "view_count"
    ]
]
# Out:
#                                                 title  view_count
# 17  What's the BEST Tech Career in 2026 ? | High P...     1058604
# 36  How to Start Coding ? Learn Programming for Be...      965976
# 23          Complete Python Learning RoadMap (A to Z)      740179
# 16  What is RAG ? | Completely Explained in 15 Min...      538041
# 41    How he got selected in Zomato - DSA preparation      526024
# 20                       How to start AI/ML in 2026 ?      476588
# 18  The Complete Data Science RoadMap | from Basic...      469395
# 27       17 LPA+ @ HPE : Best Strategy for Placement🚀      433596
# 44  How he got placed in Zomato as Software Engine...      404773
# 25  The most important TIME in College. Importance...      397156

# %%
plt.figure(figsize=(12,6))

plt.barh(

    top_views["title"],

    top_views["view_count"]

)

plt.title("Top Viewed Videos")

plt.show()
# Out:
# f:\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128640 (\N{ROCKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
top_like = videos_df.nlargest(
    10,
    "like_count"
)

top_like[
    [
        "title",
        "like_count"
    ]
]
# Out:
#                                                 title  like_count
# 36  How to Start Coding ? Learn Programming for Be...       38775
# 17  What's the BEST Tech Career in 2026 ? | High P...       38032
# 23          Complete Python Learning RoadMap (A to Z)       29298
# 18  The Complete Data Science RoadMap | from Basic...       19351
# 27       17 LPA+ @ HPE : Best Strategy for Placement🚀       19216
# 20                       How to start AI/ML in 2026 ?       17721
# 41    How he got selected in Zomato - DSA preparation       16982
# 25  The most important TIME in College. Importance...       16204
# 16  What is RAG ? | Completely Explained in 15 Min...       14137
# 15  WAKE UP CALL for 1st, 2nd year students - Know...       13940

# %%
plt.figure(figsize=(12,6))

plt.barh(

    top_like["title"],

    top_like["like_count"]

)

plt.title("Top Liked Videos")

plt.show()
# Out:
# f:\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128640 (\N{ROCKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
top_comment = videos_df.nlargest(
    10,
    "comment_count"
)

top_comment[
    [
        "title",
        "comment_count"
    ]
]
# Out:
#                                                 title  comment_count
# 36  How to Start Coding ? Learn Programming for Be...           1833
# 17  What's the BEST Tech Career in 2026 ? | High P...           1810
# 23          Complete Python Learning RoadMap (A to Z)           1303
# 20                       How to start AI/ML in 2026 ?           1037
# 35  Complete Placement Preparation: DSA + Web Deve...           1004
# 18  The Complete Data Science RoadMap | from Basic...            933
# 13  Complete Placement Preparation : Full Web Deve...            905
# 15  WAKE UP CALL for 1st, 2nd year students - Know...            843
# 22  New Complete AI/ML Batch | AI Engineering & Da...            838
# 9   Complete Full Stack Web Development Preparatio...            746

# %%
plt.figure(figsize=(12,6))

plt.barh(

    top_comment["title"],

    top_comment["comment_count"]

)

plt.title("Top Commented Videos")

plt.show()
# Out:
# f:\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128640 (\N{ROCKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# # 📌 Summary

# The Exploratory Data Analysis successfully examined the collected YouTube dataset.

# ### Key Findings

# - Loaded all tables from PostgreSQL
# - Verified data quality
# - Analyzed channel statistics
# - Explored video engagement metrics
# - Identified top-performing videos
# - Prepared dataset for NLP Analysis

# The next notebook focuses on detailed NLP analysis using the engineered features and prediction results generated during the ETL pipeline.

# %%
plt.figure(figsize=(8,5))

comments_df["comment_length"].value_counts().plot(
    kind="bar"
)

plt.title("Comment Length Distribution")

plt.xlabel("Comment Length")

plt.ylabel("Number of Comments")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    comments_df["word_count"],
    bins=30
)

plt.title("Word Count Distribution")

plt.xlabel("Words")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(
    comments_df["character_count"],
    bins=30
)

plt.title("Character Count Distribution")

plt.xlabel("Characters")

plt.ylabel("Frequency")

plt.show()

# %%
comments_df["contains_question"].value_counts()
# Out:
# contains_question
# False    3468
# True      732
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))

comments_df["contains_question"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")

plt.title("Comments Containing Questions")

plt.show()

# %%
comments_df["contains_exclamation"].value_counts()
# Out:
# contains_exclamation
# False    4076
# True      124
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))

comments_df["contains_exclamation"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")

plt.title("Comments Containing Exclamation")

plt.show()

# %%
comments_df["is_spam"].value_counts()
# Out:
# is_spam
# False    4169
# True       31
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))

comments_df["is_spam"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")

plt.title("Spam vs Normal Comments")

plt.show()

# %%
comments_df["sentiment"].value_counts()
# Out:
# sentiment
# Neutral     2013
# Positive    1976
# Negative     211
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))

comments_df["sentiment"].value_counts().plot(
    kind="bar"
)

plt.title("Sentiment Distribution")

plt.xlabel("Sentiment")

plt.ylabel("Comments")

plt.show()

# %%
comments_df["contains_abusive_language"].value_counts()
# Out:
# contains_abusive_language
# False    3912
# True      288
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))

comments_df["contains_abusive_language"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.ylabel("")

plt.title("Abusive Language Detection")

plt.show()

# %%
comments_df["word_count"].mean()
# Out:
# np.float64(14.87452380952381)

# %%
comments_df["character_count"].mean()
# Out:
# np.float64(80.00023809523809)

# %%
comments_df.nlargest(
    5,
    "character_count"
)[
    [
        "author",
        "character_count",
        "comment"
    ]
]
# Out:
#                       author  character_count  \
# 1300  @Akashcubetechnical001             3173
# 2207            @Hazard_1211             3150
# 545             @Hazard_1211             2809
# 2500     @Pareeshy_Jahanzaib             2194
# 1195     @durganandsingh1088             1609
#
#                                                 comment
# 1300  Timestamps (Powered by Merlin AI)\n00:22 - Fiv...
# 2207  print("\033")\nprint("""\n██╗  ██╗███████╗...
# 545   print("\033")\nprint("""\n██╗  ██╗███████╗...
# 2500  Please make a video on file handling in c++ .....
# 1195  I would like to share my honest experience wit...

# %%
comments_df.nlargest(
    10,
    "likes"
)[
    [
        "author",
        "likes",
        "comment"
    ]
]
# Out:
#                     author  likes  \
# 3857  @ApnaCollegeOfficial    381
# 3160     @prasinrajput4122    326
# 2105  @ApnaCollegeOfficial    316
# 500         @HarshArora773    299
# 3158    @Priyanshiii-px1mr    275
# 1151  @ApnaCollegeOfficial    271
# 614               @AURANOT    256
# 1316     @samayagarwal-l4v    254
# 1640        @Prabhav-v6xks    249
# 2836        @ShitalFatpure    215
#
#                                                 comment
# 3857  'Luck' matters in short run, BUT in the Long R...
# 3160  An interview is the conversation between two l...
# 2105  Well we are not children anymore but for our i...
# 500                     Sigma students attendance here🔥
# 3158          Sigma & Delta students attendance here🚀👇🏻
# 1151  All of us may not have equal talents, but all ...
# 614   Your look 🗿\nYour education 🗿\nYour skills 🗿\n...
# 1316  most of the students who got placed from my co...
# 1640                        Sigma students attendance ⬇
# ...

# %%
videos_df[
    [
        "title",
        "like_count"
    ]
].sort_values(
    by="like_count",
    ascending=False
).head(10)
# Out:
#                                                 title  like_count
# 36  How to Start Coding ? Learn Programming for Be...       38775
# 17  What's the BEST Tech Career in 2026 ? | High P...       38032
# 23          Complete Python Learning RoadMap (A to Z)       29298
# 18  The Complete Data Science RoadMap | from Basic...       19351
# 27       17 LPA+ @ HPE : Best Strategy for Placement🚀       19216
# 20                       How to start AI/ML in 2026 ?       17721
# 41    How he got selected in Zomato - DSA preparation       16982
# 25  The most important TIME in College. Importance...       16204
# 16  What is RAG ? | Completely Explained in 15 Min...       14137
# 15  WAKE UP CALL for 1st, 2nd year students - Know...       13940

# %%
# # 📌 NLP Analysis Summary

# ### Key Observations

# - Analyzed comment length distribution.
# - Calculated word and character statistics.
# - Examined spam detection results.
# - Explored sentiment distribution.
# - Investigated abusive language occurrences.
# - Identified highly liked comments.
# - Reviewed longest comments.

# The processed dataset is now fully ready for business insight generation and advanced visualization.

# %%
import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

# %%
numeric_df = comments_df.select_dtypes(include=["int64", "float64", "bool"])

correlation = numeric_df.corr()

correlation
# Out:
#                               likes  is_cleaned   is_spam  \
# likes                      1.000000         NaN -0.010298
# is_cleaned                      NaN         NaN       NaN
# is_spam                   -0.010298         NaN  1.000000
# contains_abusive_language  0.014018         NaN  0.020630
# is_spam_checked                 NaN         NaN       NaN
# is_sentiment_checked            NaN         NaN       NaN
# is_abusive_checked              NaN         NaN       NaN
# word_count                 0.008407         NaN  0.020114
# character_count            0.012837         NaN  0.013673
# contains_link              0.016427         NaN -0.008667
# contains_question         -0.046154         NaN  0.033709
# contains_exclamation       0.047759         NaN -0.015040
# is_feature_engineered           NaN         NaN       NaN
#
#                            contains_abusive_language  is_spam_checked  \
# likes                                       0.014018              NaN
# ...

# %%
plt.figure(figsize=(12,8))

plt.imshow(
    correlation,
    cmap="coolwarm",
    aspect="auto"
)

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=90
)

plt.yticks(
    range(len(correlation.columns)),
    correlation.columns
)

plt.colorbar()

plt.title("Correlation Matrix")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    videos_df["view_count"],
    videos_df["like_count"]
)

plt.xlabel("Views")

plt.ylabel("Likes")

plt.title("Views vs Likes")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    videos_df["view_count"],
    videos_df["comment_count"]
)

plt.xlabel("Views")

plt.ylabel("Comments")

plt.title("Views vs Comments")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    videos_df["like_count"],
    videos_df["comment_count"]
)

plt.xlabel("Likes")

plt.ylabel("Comments")

plt.title("Likes vs Comments")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.boxplot(
    videos_df["view_count"]
)

plt.title("View Count Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.boxplot(
    videos_df["like_count"]
)

plt.title("Like Count Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.boxplot(
    videos_df["comment_count"]
)

plt.title("Comment Count Distribution")

plt.show()

# %%
summary = pd.DataFrame({

    "Average Views":[

        videos_df["view_count"].mean()

    ],

    "Average Likes":[

        videos_df["like_count"].mean()

    ],

    "Average Comments":[

        videos_df["comment_count"].mean()

    ],

    "Average Words":[

        comments_df["word_count"].mean()

    ],

    "Average Characters":[

        comments_df["character_count"].mean()

    ]

})

summary
# Out:
#    Average Views  Average Likes  Average Comments  Average Words  \
# 0      272673.24        9396.06            425.64      14.874524
#
#    Average Characters
# 0           80.000238

# %%
videos_df.nlargest(

    5,

    "view_count"

)[

    [

        "title",

        "view_count",

        "like_count",

        "comment_count"

    ]

]
# Out:
#                                                 title  view_count  like_count  \
# 17  What's the BEST Tech Career in 2026 ? | High P...     1058604       38032
# 36  How to Start Coding ? Learn Programming for Be...      965976       38775
# 23          Complete Python Learning RoadMap (A to Z)      740179       29298
# 16  What is RAG ? | Completely Explained in 15 Min...      538041       14137
# 41    How he got selected in Zomato - DSA preparation      526024       16982
#
#     comment_count
# 17           1810
# 36           1833
# 23           1303
# 16            512
# 41             66

# %%
comments_df[

    comments_df["sentiment"]=="Positive"

].head(10)
# Out:
#                     comment_id     video_id                author  \
# 1   Ugwtpj36gDxyrVsoh_t4AaABAg  oGdt3tzo074      @RajeevMishra498
# 2   UgwvhcaqBZYWrCRlgRB4AaABAg  Tc_MJZ8XYYc    @parthvibhagat8272
# 3   Ugww-l1mXA_nwkbUkb14AaABAg  sMUWg_OlbbY        @himeshkar-g2f
# 7   Ugx99lyEJaaqHk5Yq554AaABAg  5S0z61DLz6M  @ApnaCollegeOfficial
# 8   UgxEsZK1F2tTH1TVGOp4AaABAg  RzH5P-f4abg   @AnshikaGoswami-d7k
# 9   UgxEx1txxy9b_4TbjlV4AaABAg  OsALYgEzJu8         @Aspirant-n8g
# 13  UgxMQ1EfSvV2NlB2VZB4AaABAg  oGdt3tzo074    @divyanshagrawal94
# 15  UgxPq12ETi4x5-jZQbt4AaABAg  tkZmtsNPdHc         @Pragatikadgi
# 16  UgxQ2_4_W7NLx1ZOZUt4AaABAg  Ty8gcCKuwNI      @hemantparab9371
# 17  UgxQSyiog1uDHcGN4m54AaABAg  6MYVWdoeW2A        @AryaPatil-r9w
#
#                                               comment  likes  \
# 1               Pls make an video on software Testing      0
# 2   Hi ma'am, are you providing Data science roles...      0
# ...

# %%
comments_df[

    comments_df["sentiment"]=="Negative"

].head(10)
# Out:
#                      comment_id     video_id                           author  \
# 18   UgxQX5aPR9NJMMNKU6B4AaABAg  Q81YQelRkCs  @SIDDALASAIKUMARSIDDALASAIKUMAR
# 22   UgxQhzxtQT-orTwluDN4AaABAg  qvUxG2a8QHs                    @shoaib-c2k2c
# 37   UgwE0JDwAVAS3ihA9al4AaABAg  oGdt3tzo074                       @ZyraMooon
# 49   Ugw42ug9bM6Ht3IP7mJ4AaABAg  Q81YQelRkCs               @shinewithshraddha
# 57   UgxxM0TqmjkeY1xM9Ut4AaABAg  Q81YQelRkCs                 @stilloptimist15
# 69   UgwTKPoC--RUVZzGcd94AaABAg  ajtCfEstvvw                   @faridalam2949
# 113  Ugy-Nw1SVZRGIG9cb1p4AaABAg  tkJdbRDtktk                      @LGupta-u2w
# 122  Ugz6NxydALm9q2LyM3F4AaABAg  tkJdbRDtktk          @nabarunchakraborty5264
# 178  Ugy4sdnCTJks4lzst6h4AaABAg  w9319SXPOmg                 @abhayshukla7471
# 209  UgwnGorHy7bQJeSgskV4AaABAg  0MCD9Y5e0o8                       @dhavewala
#
#                                                comment  likes  \
# ...

# %%
comments_df[

    comments_df["is_spam"]

].head(10)
# Out:
#                       comment_id     video_id                author  \
# 83    UgycY2j9t55oIMvnJ394AaABAg  uNZwUdfU43Q            @Dyson2024
# 96    UgzytfKhXpRafth9KNN4AaABAg  uNZwUdfU43Q       @JasirDar-wn3dy
# 185   Ugwc57i0TZgOco1Ur494AaABAg  Ty8gcCKuwNI       @krishkumar3124
# 213   Ugwnf9725DHnIy21SHd4AaABAg  qvUxG2a8QHs           @DARSHU-FFM
# 251   Ugx59Z_xd6iWimfpJD54AaABAg  1wMPoHDz8lw    @Muskankhatoon-q3o
# 316   UgzLeoTsdIFazBMWnid4AaABAg  FMOtyYU6pj8       @ArmanAli-m4q9x
# 391   UgyIYggXV1YvnXre0nZ4AaABAg  -SV_PtdB51Y   @shripadshiraskar01
# 1011  Ugx15aGo0yiEJZI2zMZ4AaABAg  BvKxCCVNXrY   @shaikzakiahmed3252
# 1157  UgxqYXtayuk-w1yA4aF4AaABAg  uNZwUdfU43Q  @sujatavkhandale3935
# 1416  UgyfbBE4-96rPPT8UdZ4AaABAg  uNZwUdfU43Q          @SbGamer-x6y
#
#                                                 comment  likes  \
# 83    I HAVE DELTA 7.0 ANYONE WANT PLEASE MESSAGE ME...      1
# 96                                       can i join now      0
# ...

# %%
comments_df[

    comments_df["contains_abusive_language"]

].head(10)
# Out:
#                     comment_id     video_id               author  \
# 8   UgxEsZK1F2tTH1TVGOp4AaABAg  RzH5P-f4abg  @AnshikaGoswami-d7k
# 9   UgxEx1txxy9b_4TbjlV4AaABAg  OsALYgEzJu8        @Aspirant-n8g
# 30  UgxTm3ZukCgkjAIe7eZ4AaABAg  RzH5P-f4abg        @Shweta-mt5oy
# 42  Ugxbc9Im1WFaqkcIXO54AaABAg  c-HkAo8Bho4    @TANUSHREEDAS-d2r
# 52  UgwO6LrUgYV6UICSy6h4AaABAg  w9319SXPOmg   @AbhishekKumar-454
# 58  Ugxy0W7MvA3ULt2OBZB4AaABAg  zk_8gJqrlxY   @KnowledgeInfo-u3w
# 59  UgxzHOvq4KIike6Ipol4AaABAg  bFQOsMt4Ex8          @KaunChlega
# 64  UgwScxXavljgAyaXQbJ4AaABAg  FMOtyYU6pj8           @FuYdh-d2d
# 69  UgwTKPoC--RUVZzGcd94AaABAg  ajtCfEstvvw       @faridalam2949
# 71  UgwTKzbWVli2dYUkGGJ4AaABAg  Tc_MJZ8XYYc     @Vinay_tech_zone
#
#                                               comment  likes  \
# 8   Hii  \nI currently completed my 12 boards with...      0
# 9   Hello Shraddha Ma’am,\nI really need your guid...      0
# 30  Hello Apna College team, I purchased the Sigma...      2
# ...

# %%
print("Channels :",len(channels_df))

print("Videos :",len(videos_df))

print("Comments :",len(comments_df))

print()

print("Positive :",comments_df["sentiment"].value_counts()["Positive"])

print("Neutral :",comments_df["sentiment"].value_counts()["Neutral"])

print("Negative :",comments_df["sentiment"].value_counts()["Negative"])
# Out:
# Channels : 1
# Videos : 50
# Comments : 4200
#
# Positive : 1976
# Neutral : 2013
# Negative : 211

# %%
spam_percentage = (

comments_df["is_spam"].mean()

)*100

print(

f"Spam Percentage : {spam_percentage:.2f}%"

)
# Out:
# Spam Percentage : 0.74%

# %%
abusive_percentage=(

comments_df["contains_abusive_language"].mean()

)*100

print(

f"Abusive Percentage : {abusive_percentage:.2f}%"

)
# Out:
# Abusive Percentage : 6.86%

# %%
print("========== BUSINESS INSIGHTS ==========\n")

print(

f"Total Videos : {len(videos_df)}"

)

print(

f"Total Comments : {len(comments_df)}"

)

print(

f"Average Views : {videos_df['view_count'].mean():,.0f}"

)

print(

f"Average Likes : {videos_df['like_count'].mean():,.0f}"

)

print(

f"Average Comments : {videos_df['comment_count'].mean():,.0f}"

)

print(

f"Spam Percentage : {spam_percentage:.2f}%"

)

print(

f"Positive Comments : {(comments_df['sentiment']=='Positive').mean()*100:.2f}%"

)

print(

f"Negative Comments : {(comments_df['sentiment']=='Negative').mean()*100:.2f}%"

)
# Out:
# ========== BUSINESS INSIGHTS ==========
#
# Total Videos : 50
# Total Comments : 4200
# Average Views : 272,673
# Average Likes : 9,396
# Average Comments : 426
# Spam Percentage : 0.74%
# Positive Comments : 47.05%
# Negative Comments : 5.02%

# %%
# # 📊 Final EDA Conclusion

# ## Dataset Summary

# - Successfully extracted YouTube data using YouTube Data API.
# - Stored structured data in PostgreSQL (Neon).
# - Performed data cleaning and preprocessing.
# - Generated engineered NLP features.
# - Conducted spam detection.
# - Performed sentiment analysis.
# - Identified abusive comments.
# - Executed exploratory data analysis using Pandas and Matplotlib.

# ---

# ## Key Findings

# - Majority of comments are neutral or positive.
# - Spam comments constitute only a small fraction of the dataset.
# - Viewer engagement strongly correlates with likes and comments.
# - Longer comments generally contain more meaningful discussions.
# - Videos with higher engagement also receive higher interaction rates.

# ---
